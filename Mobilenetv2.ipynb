# %%
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-2490040756.py in <cell line: 0>()
#      15 x = Dense(128, activation='relu')(x)
#      16 x = Dropout(0.3)(x)
# ---> 17 predictions = Dense(train_data.num_classes, activation='softmax')(x)
#      18
#      19 # Combine into a final model
#
# NameError: name 'train_data' is not defined
